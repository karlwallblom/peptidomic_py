# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import xlrd
import pathlib
from pathlib import Path
import re

# %% [markdown]
# ### Skapa en Data Frame utifrån excelfiler i en Mapp + ta bort duplikater

# %%
## Läser in filerna 1 och 1 
data1 = pd.read_excel('WF/peptide_WF1.xlsx')
data1['Peptide']= data1['Peptide'].str.replace('\d+', '')
data1['Peptide']= data1['Peptide'].str.replace(r'\(\+\.\)', '')
data1['Peptide']= data1['Peptide'].apply(lambda x: x.split('.')[1] if x[1]=='.' else x.split('.')[0] if (x[1]!='.' and x[-2]=='.') else x)
data1 = data1.groupby(by=['Peptide'], as_index=False).sum()


data2 = pd.read_excel('WF/peptide_WF2.xlsx')
data2['Peptide']= data2['Peptide'].str.replace('\d+', '')
data2['Peptide']= data2['Peptide'].str.replace(r'\(\+\.\)', '')
data2['Peptide']= data2['Peptide'].apply(lambda x: x.split('.')[1] if x[1]=='.' else x.split('.')[0] if (x[1]!='.' and x[-2]=='.') else x)
data2 = data2.groupby(by=['Peptide'], as_index=False).sum()

data3 = pd.read_excel('WF/peptide_WF3.xlsx')
data3['Peptide']= data3['Peptide'].str.replace('\d+', '')
data3['Peptide']= data3['Peptide'].str.replace(r'\(\+\.\)', '')
data3['Peptide']= data3['Peptide'].apply(lambda x: x.split('.')[1] if x[1]=='.' else x.split('.')[0] if (x[1]!='.' and x[-2]=='.') else x)
data3 = data3.groupby(by=['Peptide'], as_index=False).sum()

data4 = pd.read_excel('WF/peptide_WF4.xlsx')
data4['Peptide']= data4['Peptide'].str.replace('\d+', '')
data4['Peptide']= data4['Peptide'].str.replace(r'\(\+\.\)', '')
data4['Peptide']= data4['Peptide'].apply(lambda x: x.split('.')[1] if x[1]=='.' else x.split('.')[0] if (x[1]!='.' and x[-2]=='.') else x)
data4 = data4.groupby(by=['Peptide'], as_index=False).sum()

data5 = pd.read_excel('WF/peptide_WF5.xlsx')
data5['Peptide']= data5['Peptide'].str.replace('\d+', '')
data5['Peptide']= data5['Peptide'].str.replace(r'\(\+\.\)', '')
data5['Peptide']= data5['Peptide'].apply(lambda x: x.split('.')[1] if x[1]=='.' else x.split('.')[0] if (x[1]!='.' and x[-2]=='.') else x)
data5 = data5.groupby(by=['Peptide'], as_index=False).sum()
data5
# Out:
#                      Peptide  -10lgP       Mass  Length  ppm        m/z  \
# 0                AAFNSGKVDIV   33.47  1119.5924      11  0.4   560.8037
# 1       AAGSDVDIDMAFILDSAETT   29.39  2056.9146      20  0.9  1029.4655
# 2       AALLSPYSYSTTAVVTNPKE   90.18  2111.0786      20  2.4  1056.5491
# 3     AAMSTYTGIFTDQVLSVLKGEE   69.94  2375.1565      22  3.0  1188.5891
# 4          AAPAPAPPPEPERPKEV   24.95  1751.9205      17  1.9   584.9819
# ...                      ...     ...        ...     ...  ...        ...
# 3211           YVDVLKDSGRDYV   38.07  1527.7568      13  2.9   764.8879
# 3212              YVNKEIQNAV   33.21  1176.6139      10 -4.3   589.3117
# 3213           YVNKEIQNAVNGV   37.53  1448.7147      13  3.5   725.3672
# 3214              YWKALGISPF   40.46  1180.6281      10  5.1   591.3243
# 3215           YYLQGAKIPKPEA   24.63  1476.7976      13  3.9   493.2751
#
#           RT    Area WF5  Fraction  #Feature  #Feature WF5
# ...

# %%
data1['Peptide'].to_clipboard(sep='\n', index=False)
data1
# Out:
#                      Peptide  -10lgP       Mass  Length  ppm        m/z  \
# 0                AAFNSGKVDIV   54.47  1119.5924      11  1.8   560.8045
# 1              AAFNSGKVDIVAI   43.73  1303.7135      13  4.1   652.8667
# 2       AAGSDVDIDMAFILDSAETT   61.04  2056.9146      20  4.6  1029.4692
# 3                AAHLPAEFTPA   28.01  1123.5662      11  2.8   562.7919
# 4               AAHLPAEFTPAV   40.68  1222.6345      12  1.3   612.3253
# ...                      ...     ...        ...     ...  ...        ...
# 3489              YVNDAFGTAH   30.28  1093.4829      10  4.6   547.7512
# 3490      YVYKVLKQVHPDTGISSK   33.04  2061.1257      18  2.1   688.0506
# 3491  YVYKVLKQVHPDTGISSKAMGI   31.19  2449.3040      22  1.8   817.4434
# 3492           YYLQGAKIPKPEA   39.16  1476.7976      13  0.8   493.2735
# 3493      YYLQGAKIPKPEASFSPR   49.10  2051.0840      18 -1.2   513.7776
#
#           RT    Area WF1  Fraction  #Feature  #Feature WF1
# ...

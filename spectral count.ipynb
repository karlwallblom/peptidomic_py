# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import xlrd
from openpyxl import load_workbook
### vilken mapp vill du kolla i? INF
## Skapar en lista över excelfilerna i mappen
files = os.listdir('protein-peptide_sample_inf')
files_xls = [f for f in files if f[-3:] == 'lsx']
## Läser in filerna 1 och 1 och appendar dom i df_inf
df_inf = pd.DataFrame()
for f in files_xls:
    data = pd.read_excel('protein-peptide_sample_inf' + '/' + f)
    ## sortera bort om feature<4
    data = data.loc[(data['#Feature'] >= 4)]
    ## Tar bort allt ur kolummn som inte är bokstäver + ta bort upp och nedströms AA
    data['Peptide']= data['Peptide'].str.replace('\d+', '')
    data['Peptide']= data['Peptide'].str.replace(r'\(\+\.\)', '')
    data['Peptide']= data['Peptide'].apply(lambda x: x.split('.')[1] if x[1]=='.' else x.split('.')[0] if (x[1]!='.' and x[-2]=='.') else x)
    data['count'] = 1
    ## Summerar Peptides, sparar protein info
    data = data.groupby(by=['Peptide', 'Protein Accession'], as_index=False).sum()
    data['End'] = data['End']/ data['count']
    data['Start'] = data['Start']/ data['count']
    df_inf = df_inf.append(data)
df_inf['count']=1
df_inf = df_inf.groupby(by=['Peptide','Protein Accession'], as_index=False).sum()
df_inf['End']=df_inf['End']/df_inf['count']
df_inf['Start']=df_inf['Start']/df_inf['count']
df_inf=df_inf.drop(columns='count')
df_inf = df_inf [['Peptide','Protein Accession', 'Start','End', '#Feature']]    
### vilken mapp vill du kolla i? ninf
## Skapar en lista över excelfilerna i mappen
files = os.listdir('protein-peptide_sample_ninf')
files_xls = [f for f in files if f[-3:] == 'lsx']
## Läser in filerna 1 och 1 och appendar dom i df_ninf
df_ninf = pd.DataFrame()
for f in files_xls:
    data = pd.read_excel('protein-peptide_sample_ninf' + '/' + f)
    ## sortera bort om feature<4
    data = data.loc[(data['#Feature'] >= 4)]
    ## Tar bort allt ur kolummn som inte är bokstäver + ta bort upp och nedströms AA
    data['Peptide']= data['Peptide'].str.replace('\d+', '')
    data['Peptide']= data['Peptide'].str.replace(r'\(\+\.\)', '')
    data['Peptide']= data['Peptide'].apply(lambda x: x.split('.')[1] if x[1]=='.' else x.split('.')[0] if (x[1]!='.' and x[-2]=='.') else x)
    data['count'] = 1
    ## Summerar Peptides, sparar protein ninfo
    data = data.groupby(by=['Peptide', 'Protein Accession'], as_index=False).sum()
    data['End'] = data['End']/ data['count']
    data['Start'] = data['Start']/ data['count']
    df_ninf = df_ninf.append(data)
df_ninf['count']=1
df_ninf = df_ninf.groupby(by=['Peptide','Protein Accession'], as_index=False).sum()
df_ninf['End']=df_ninf['End']/df_ninf['count']
df_ninf['Start']=df_ninf['Start']/df_ninf['count']
df_ninf=df_ninf.drop(columns='count')
df_ninf = df_ninf [['Peptide','Protein Accession', 'Start','End', '#Feature']]    
### vilken mapp vill du kolla i? wf
## Skapar en lista över excelfilerna i mappen
files = os.listdir('protein-peptide_sample_wf')
files_xls = [f for f in files if f[-3:] == 'lsx']
## Läser in filerna 1 och 1 och appendar dom i df_wf
df_wf = pd.DataFrame()
for f in files_xls:
    data = pd.read_excel('protein-peptide_sample_wf' + '/' + f)
    ## sortera bort om feature<4
    data = data.loc[(data['#Feature'] >= 4)]
    ## Tar bort allt ur kolummn som inte är bokstäver + ta bort upp och nedströms AA
    data['Peptide']= data['Peptide'].str.replace('\d+', '')
    data['Peptide']= data['Peptide'].str.replace(r'\(\+\.\)', '')
    data['Peptide']= data['Peptide'].apply(lambda x: x.split('.')[1] if x[1]=='.' else x.split('.')[0] if (x[1]!='.' and x[-2]=='.') else x)
    data['count'] = 1
    ## Summerar Peptides, sparar protein wfo
    data = data.groupby(by=['Peptide', 'Protein Accession'], as_index=False).sum()
    data['End'] = data['End']/ data['count']
    data['Start'] = data['Start']/ data['count']
    df_wf = df_wf.append(data)
df_wf = df_wf.groupby(by=['Peptide','Protein Accession'], as_index=False).sum()
df_wf['End']=df_wf['End']/df_wf['count']
df_wf['Start']=df_wf['Start']/df_wf['count']
df_wf=df_wf.drop(columns='count')
df_wf = df_wf [['Peptide','Protein Accession', 'Start','End', '#Feature']]

# %%
df_inf = df_inf.loc[(df_inf['sp|P68871|HBB_HUMAN'])]
df_ninf = df_ninf.loc[(df_ninf['sp|P68871|HBB_HUMAN'])]
df_wf = df_wf.loc[(df_wf['sp|P68871|HBB_HUMAN'])]
# Out:
#                 Peptide    Protein Accession  Start    End  #Feature
# 0              AAHLPAEF  sp|P69905|HBA_HUMAN  111.0  118.0         4
# 1           AAHLPAEFTPA  sp|P69905|HBA_HUMAN  111.0  121.0         8
# 2          AAHLPAEFTPAV  sp|P69905|HBA_HUMAN  111.0  122.0        12
# 3         AAHLPAEFTPAVH  sp|P69905|HBA_HUMAN  111.0  123.0        19
# 4        AAHLPAEFTPAVHA  sp|P69905|HBA_HUMAN  111.0  124.0        23
# ...                 ...                  ...    ...    ...       ...
# 1848       YQKVVAGVANAL  sp|P68871|HBB_HUMAN  131.0  142.0         8
# 1849      YQKVVAGVANALA  sp|P02042|HBD_HUMAN  131.0  143.0         4
# 1850      YQKVVAGVANALA  sp|P68871|HBB_HUMAN  131.0  143.0         4
# 1851  YQKVVAGVANALAHKYH  sp|P02042|HBD_HUMAN  131.0  147.0        41
# 1852  YQKVVAGVANALAHKYH  sp|P68871|HBB_HUMAN  131.0  147.0        41
#
# [1853 rows x 5 columns]

# %%
df_wf.loc[(df_wf['Peptide']== 'SFPTTKTYFPHFDLSHGSAQVK')]
# Out:
# Empty DataFrame
# Columns: [Peptide, Protein Accession, Start, End, #Feature]
# Index: []

# %%
df_ninf.loc[(df_ninf['Peptide'] == 'SFPTTKTYFPHFDLSHGSAQVK')]
# Out:
# Empty DataFrame
# Columns: [Peptide, Protein Accession, Start, End, #Feature]
# Index: []

# %%
df_inf.loc[(df_inf['Peptide']== 'SFPTTKTYFPHFDLSHGSAQVK')]
# Out:
#                      Peptide    Protein Accession  Start   End  #Feature
# 1324  SFPTTKTYFPHFDLSHGSAQVK  sp|P69905|HBA_HUMAN   36.0  57.0         8

# %%
Protein='sp|P69905|HBA_HUMAN'
Start=33
End=76
df_wf_start=df_wf.loc[(df_wf['Start']>=Start)]
df_wf_end=df_wf_start.loc[(df_wf_start['End']<=End)]
df_wf_end=df_wf_end.loc[(df_wf_end['Protein Accession']==Protein)]
print(
df_wf_end['#Feature'].sum())
df_wf_end
# Out:
# 575
#                Peptide    Protein Accession  Start   End  #Feature
# 10            ADALTNAV  sp|P69905|HBA_HUMAN   64.0  71.0         4
# 99           ALTNAVAHV  sp|P69905|HBA_HUMAN   66.0  74.0         4
# 100         ALTNAVAHVD  sp|P69905|HBA_HUMAN   66.0  75.0         8
# 168          DALTNAVAH  sp|P69905|HBA_HUMAN   65.0  73.0         4
# 169         DALTNAVAHV  sp|P69905|HBA_HUMAN   65.0  74.0         4
# 403          FDLSHGSAQ  sp|P69905|HBA_HUMAN   47.0  55.0         8
# 404         FDLSHGSAQV  sp|P69905|HBA_HUMAN   47.0  56.0        12
# 490            FLSFPTT  sp|P69905|HBA_HUMAN   34.0  40.0        16
# 491           FLSFPTTK  sp|P69905|HBA_HUMAN   34.0  41.0        10
# 492          FLSFPTTKT  sp|P69905|HBA_HUMAN   34.0  42.0        16
# 493   FLSFPTTKTYFPHFDL  sp|P69905|HBA_HUMAN   34.0  49.0         4
# 511            FPHFDLS  sp|P69905|HBA_HUMAN   44.0  50.0        20
# 512          FPHFDLSHG  sp|P69905|HBA_HUMAN   44.0  52.0        19
# 513        FPHFDLSHGSA  sp|P69905|HBA_HUMAN   44.0  54.0         8
# 514      FPHFDLSHGSAQV  sp|P69905|HBA_HUMAN   44.0  56.0        17
# 760        HFDLSHGSAQV  sp|P69905|HBA_HUMAN   46.0  56.0        12
# 931         KVADALTNAV  sp|P69905|HBA_HUMAN   62.0  71.0        12
# 1153          MFLSFPTT  sp|P69905|HBA_HUMAN   33.0  40.0         4
# 1154         MFLSFPTTK  sp|P69905|HBA_HUMAN   33.0  41.0        20
# 1155        MFLSFPTTKT  sp|P69905|HBA_HUMAN   33.0  42.0        12
# 1723        TKTYFPHFDL  sp|P69905|HBA_HUMAN   40.0  49.0         6
# 1813           TYFPHFD  sp|P69905|HBA_HUMAN   42.0  48.0        16
# 1814          TYFPHFDL  sp|P69905|HBA_HUMAN   42.0  49.0        16
# 1815         TYFPHFDLS  sp|P69905|HBA_HUMAN   42.0  50.0        14
# 1816        TYFPHFDLSH  sp|P69905|HBA_HUMAN   42.0  51.0        21
# 1817       TYFPHFDLSHG  sp|P69905|HBA_HUMAN   42.0  52.0        29
# 1818      TYFPHFDLSHGS  sp|P69905|HBA_HUMAN   42.0  53.0        24
# 1819     TYFPHFDLSHGSA  sp|P69905|HBA_HUMAN   42.0  54.0        29
# 1820    TYFPHFDLSHGSAQ  sp|P69905|HBA_HUMAN   42.0  55.0        26
# 1822  TYFPHFDLSHGSAQVK  sp|P69905|HBA_HUMAN   42.0  57.0        16
# 1829         VADALTNAV  sp|P69905|HBA_HUMAN   63.0  71.0         8
# 1830      VADALTNAVAHV  sp|P69905|HBA_HUMAN   63.0  74.0         8
# 2049           YFPHFDL  sp|P69905|HBA_HUMAN   43.0  49.0        18
# 2050          YFPHFDLS  sp|P69905|HBA_HUMAN   43.0  50.0        12
# 2051         YFPHFDLSH  sp|P69905|HBA_HUMAN   43.0  51.0        12
# 2052        YFPHFDLSHG  sp|P69905|HBA_HUMAN   43.0  52.0        30
# 2053       YFPHFDLSHGS  sp|P69905|HBA_HUMAN   43.0  53.0         5
# 2054      YFPHFDLSHGSA  sp|P69905|HBA_HUMAN   43.0  54.0        19
# 2055     YFPHFDLSHGSAQ  sp|P69905|HBA_HUMAN   43.0  55.0        28
# 2056    YFPHFDLSHGSAQV  sp|P69905|HBA_HUMAN   34.4  44.8        24

# %%
df_ninf_start=df_ninf.loc[(df_ninf['Start']>=Start)]
df_ninf_end=df_ninf_start.loc[(df_ninf_start['End']<=End)]
df_ninf_end=df_ninf_end.loc[(df_ninf_end['Protein Accession']==Protein)]
print(
df_ninf_end['#Feature'].sum())
df_ninf_end
# Out:
# 613
#                  Peptide    Protein Accession  Start   End  #Feature
# 13           ADALTNAVAHV  sp|P69905|HBA_HUMAN   64.0  74.0        12
# 83              ALTNAVAH  sp|P69905|HBA_HUMAN   66.0  73.0         4
# 84             ALTNAVAHV  sp|P69905|HBA_HUMAN   66.0  74.0         4
# 85            ALTNAVAHVD  sp|P69905|HBA_HUMAN   66.0  75.0        10
# 129           DALTNAVAHV  sp|P69905|HBA_HUMAN   65.0  74.0         4
# ...                  ...                  ...    ...   ...       ...
# 1087        VADALTNAVAHV  sp|P69905|HBA_HUMAN   63.0  74.0         8
# 1223             YFPHFDL  sp|P69905|HBA_HUMAN   43.0  49.0         4
# 1224          YFPHFDLSHG  sp|P69905|HBA_HUMAN   43.0  52.0         4
# 1225     YFPHFDLSHGSAQVK  sp|P69905|HBA_HUMAN   43.0  57.0        19
# 1226  YFPHFDLSHGSAQVKGHG  sp|P69905|HBA_HUMAN   43.0  60.0         8
#
# [62 rows x 5 columns]

# %%
df_inf_start=df_inf.loc[(df_inf['Start']>=Start)]
df_inf_end=df_inf_start.loc[(df_inf_start['End']<=End)]
df_inf_end=df_inf_end.loc[(df_inf_end['Protein Accession']==Protein)]
print(
df_inf_end['#Feature'].sum())
df_inf_end
# Out:
# 1770
#                   Peptide    Protein Accession  Start   End  #Feature
# 27               ADALTNAV  sp|P69905|HBA_HUMAN   64.0  71.0         4
# 28             ADALTNAVAH  sp|P69905|HBA_HUMAN   64.0  73.0        17
# 29            ADALTNAVAHV  sp|P69905|HBA_HUMAN   64.0  74.0        10
# 30           ADALTNAVAHVD  sp|P69905|HBA_HUMAN   64.0  75.0         4
# 160              ALTNAVAH  sp|P69905|HBA_HUMAN   66.0  73.0         9
# ...                   ...                  ...    ...   ...       ...
# 1816        YFPHFDLSHGSAQ  sp|P69905|HBA_HUMAN   43.0  55.0        10
# 1817       YFPHFDLSHGSAQV  sp|P69905|HBA_HUMAN   43.0  56.0         5
# 1818      YFPHFDLSHGSAQVK  sp|P69905|HBA_HUMAN   43.0  57.0        16
# 1819   YFPHFDLSHGSAQVKGHG  sp|P69905|HBA_HUMAN   43.0  60.0         5
# 1820  YFPHFDLSHGSAQVKGHGK  sp|P69905|HBA_HUMAN   43.0  61.0        16
#
# [160 rows x 5 columns]
